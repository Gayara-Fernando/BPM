# %%
# Okay, let's get the proper transformations, and also get all the predictions on a subwindow scale - Later as a proof of concept, we will separate the sequences with densities all zero and see how the predicted densities look like.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr

# %%
# path to dataframes
path_to_dfs = "data/BLAR_implementation/Block_0303/forecasted_counts"

# %%
len(os.listdir(path_to_dfs))
# Out:
# 9632

# %%
len(os.listdir(path_to_dfs)) / 1376
# Out:
# 7.0

# %%
averaged_forecasts_csvs = []
for file in os.listdir(path_to_dfs):
    if file[:8] =='averaged':
        averaged_forecasts_csvs.append(file)

# %%
# how many csv files do we have?
len(averaged_forecasts_csvs)
# Out:
# 1376

# %%
averaged_forecasts_csvs[0]
# Out:
# 'averaged_forecasts_sub_986.csv'

# %%
# let's create these names in the order of the subwindows
ordered_csv_files = ['averaged_forecasts_sub_' + str(i) + '.csv' for i in range(1376)]

# %%
# ordered_csv_files

# %%
# %%time
all_dfs = []
for file in ordered_csv_files:
    read_df = pd.read_csv(path_to_dfs + '/' + file)
    all_dfs.append(read_df)
# Out:
# CPU times: user 2.32 s, sys: 469 ms, total: 2.79 s
# Wall time: 33.5 s

# %%
# make a single dataframe out of the many
combined_df = pd.concat(all_dfs, axis = 1)

# %%
combined_df.head()
# Out:
#    True_value  Forecasted_value  True_value  Forecasted_value  True_value  \
# 0    2.196945          1.723513    2.190874          1.753550    2.072379
# 1    2.079442          1.659088    2.011892          1.677310    1.847915
# 2    2.079355          1.587174    1.975556          1.592074    1.943747
# 3    1.945910          1.642736    1.938099          1.687387    1.791983
# 4    1.609444          1.586603    1.604923          1.598426    1.387891
#
#    Forecasted_value  True_value  Forecasted_value  True_value  \
# 0          1.751174    1.945657          1.701996    2.066080
# 1          1.681853    1.945910          1.630850    2.025481
# 2          1.589931    1.945016          1.557544    1.946993
# 3          1.658105    2.015022          1.620888    2.197220
# 4          1.565213    1.783839          1.539802    1.794056
#
#    Forecasted_value  ...  True_value  Forecasted_value  True_value  \
# 0          1.817379  ...    0.000673          0.034233    0.000673
# 1          1.740645  ...    0.000000          0.029122    0.000000
# 2          1.652480  ...    0.000000          0.019676    0.000000
# 3          1.684921  ...    0.000000          0.028666    0.000000
# 4          1.630286  ...    0.414057          0.038314    0.414057
#
#    Forecasted_value  True_value  Forecasted_value    True_value  \
# 0          0.038783    0.000489          0.039195  8.526243e-09
# 1          0.032712    0.000000          0.036001  0.000000e+00
# 2          0.023030    0.000000          0.027455  0.000000e+00
# 3          0.035167    0.000000          0.033038  0.000000e+00
# 4          0.041017    0.414057          0.035064  4.140566e-01
#
#    Forecasted_value  True_value  Forecasted_value
# 0          0.039165    0.000000         -0.000720
# 1          0.034382    0.000000          0.000533
# 2          0.025320    0.000000          0.000884
# 3          0.032421    0.000000          0.001146
# 4          0.035514    0.395894          0.000655
#
# [5 rows x 2752 columns]

# %%
combined_df.shape
# Out:
# (7, 2752)

# %%
# get the true values
True_values_df = combined_df[['True_value']]

# %%
True_values_df.head()
# Out:
#    True_value  True_value  True_value  True_value  True_value  True_value  \
# 0    2.196945    2.190874    2.072379    1.945657    2.066080    2.197150
# 1    2.079442    2.011892    1.847915    1.945910    2.025481    2.226882
# 2    2.079355    1.975556    1.943747    1.945016    1.946993    2.198916
# 3    1.945910    1.938099    1.791983    2.015022    2.197220    2.197224
# 4    1.609444    1.604923    1.387891    1.783839    1.794056    1.794056
#
#    True_value  True_value  True_value  True_value  ...  True_value  \
# 0    2.306715    2.290594    1.996578    1.856985  ...    0.000673
# 1    2.298064    2.182153    2.032444    1.638317  ...    0.000000
# 2    2.219461    1.992509    1.926758    1.650830  ...    0.000000
# 3    2.197077    1.962260    1.782418    1.395338  ...    0.000000
# 4    1.707248    1.607678    1.212041    1.103189  ...    0.414057
#
#    True_value  True_value  True_value  True_value  True_value  True_value  \
# 0    0.000673    0.000673    0.000673    0.000673    0.000673    0.000673
# 1    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 2    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 3    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 4    0.414057    0.414057    0.414057    0.414057    0.414057    0.414057
#
#    True_value    True_value  True_value
# 0    0.000489  8.526243e-09    0.000000
# 1    0.000000  0.000000e+00    0.000000
# 2    0.000000  0.000000e+00    0.000000
# 3    0.000000  0.000000e+00    0.000000
# 4    0.414057  4.140566e-01    0.395894
#
# [5 rows x 1376 columns]

# %%
True_values_df.shape
# Out:
# (7, 1376)

# %%
# get the proper counts? - Do the transformation
exp_true = np.exp(True_values_df)-1

# %%
exp_true
# Out:
#    True_value  True_value  True_value  True_value  True_value  True_value  \
# 0    7.997484    7.943025    6.943698    5.998227    6.893819    7.999327
# 1    7.000000    6.477448    5.346575    5.999997    6.579756    8.270914
# 2    6.999308    6.210626    5.984875    5.993741    6.007584    8.015235
# 3    5.999997    5.945537    5.001344    6.500894    7.999962    7.999996
# 4    4.000031    3.977478    3.006390    4.952668    5.013793    5.013792
# 5    4.000000    3.997484    3.022552    3.213816    5.477417    5.999999
# 6    4.000000    4.000000    3.945540    3.000674    3.000000    3.500000
#
#    True_value  True_value  True_value  True_value  ...  True_value  \
# 0    9.041387    8.880806    6.363811    5.404401  ...    0.000674
# 1    8.954896    7.865375    6.632716    4.146502  ...    0.000000
# 2    8.202369    6.333913    5.867211    4.211305  ...    0.000000
# 3    7.998670    6.115386    4.944212    3.036338  ...    0.000000
# 4    4.513766    3.991206    2.360337    2.013762  ...    0.512943
# 5    5.491893    3.352160    3.000000    3.000000  ...    0.000674
# 6    4.000000    3.998674    2.824365    2.000030  ...    0.000000
#
#    True_value  True_value    True_value  True_value  True_value  True_value  \
# 0    0.000674    0.000674  6.737195e-04    0.000674    0.000674    0.000674
# 1    0.000000    0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 2    0.000000    0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 3    0.000000    0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 4    0.512943    0.512943  5.129428e-01    0.512943    0.512943    0.512943
# 5    0.000674    0.000597  1.044816e-07    0.000000    0.000000    0.000000
# 6    0.000000    0.000000  0.000000e+00    0.000000    0.000000    0.000000
#
#    True_value    True_value  True_value
# 0    0.000489  8.526243e-09    0.000000
# 1    0.000000  0.000000e+00    0.000000
# 2    0.000000  0.000000e+00    0.000000
# 3    0.000000  0.000000e+00    0.000000
# 4    0.512943  5.129428e-01    0.485712
# 5    0.000000  0.000000e+00    0.000000
# 6    0.000000  0.000000e+00    0.000000
#
# [7 rows x 1376 columns]

# %%
# Identify the maximum and the minimum true values we have for the test data

# %%
exp_true.values.min(), exp_true.values.max()
# Out:
# (0.0, 10.74842430108513)

# %%
# Okay, so the highest true value we have is ~3. let's get teh min and max values for the predicted exponentiated values also

# %%
all_forecasts_npy_files = []
for file in os.listdir(path_to_dfs):
    if file[:13] == 'all_forecasts':
        all_forecasts_npy_files.append(file)

# %%
len(all_forecasts_npy_files)
# Out:
# 1376

# %%
all_forecasts_npy_files[0]
# Out:
# 'all_forecasts_sub_1104.npy'

# %%
# load just the first file
sub_273_forecasts = np.load(os.path.join(path_to_dfs, all_forecasts_npy_files[0]))

# %%
sub_273_forecasts.shape
# Out:
# (1000, 4, 7)

# %%
# Okay, so for the subwindow 273 -  this file seem to have all the 1000 values in the 4 chains for all the test time points in the sequence

# %%
# transform these values?
sub_273_forecasts = np.exp(sub_273_forecasts) - 1

# %%
sub_273_forecasts.min(), sub_273_forecasts.max()
# Out:
# (-0.9398121, 125.39564)

# %%
# get rid of anything below zero?
sub_273_forecasts[sub_273_forecasts < 0] = 0

# %%
sub_273_forecasts.min(), sub_273_forecasts.max()
# Out:
# (0.0, 125.39564)

# %%
# cool -  what does these values mean?

# %%
# try averaging the forecasted values along the 0th and 1st axis?

# %%
sub_273_forecasts_averged = np.mean(sub_273_forecasts, axis = (0,1))

# %%
sub_273_forecasts_averged
# Out:
# array([1.922656 , 1.9438637, 1.8583279, 1.9949199, 1.9914982, 1.9708732,
#        1.8899862], dtype=float32)

# %%
sub_273_forecasts_averged.shape
# Out:
# (7,)

# %%
# sanity check

# %%
# sanity check
for i in range(sub_273_forecasts.shape[-1]):
    track = sub_273_forecasts[:,:,i]
    print(np.mean(track))
# Out:
# 1.9226562
# 1.9438635
# 1.858329
# 1.9949208
# 1.9914972
# 1.970874
# 1.8899863

# %%
# Verify the shape of the true values - these are at a subwindow level, and we can use these as they are for getting the metrics, and the scatterplots?

# %%
exp_true.shape
# Out:
# (7, 1376)

# %%
# Okay, we need the predictions for the subwindows in the same shape? - but before that, we need to do the transformation for all the npy files. We can do this in a loop - we have done this before, use the code as it is.

# %%
# %%time
catch_all_averaged_preds = []
for i in range(exp_true.shape[1]):
    file_name = "all_forecasts_sub_" + str(i) + '.npy'
    al_forecasts_npy_file = np.load(os.path.join(path_to_dfs, file_name))
    # make the conversion
    sub_window_forecasts = np.exp(al_forecasts_npy_file) - 1
    # get rid of anything below zero?
    sub_window_forecasts[sub_window_forecasts < 0] = 0
    # get averages over time 
    sub_window_forecasts_averaged = np.mean(sub_window_forecasts, axis = (0,1))
    catch_all_averaged_preds.append(sub_window_forecasts_averaged)
# Out:
# CPU times: user 1.11 s, sys: 529 ms, total: 1.64 s
# Wall time: 28.6 s

# %%
len(catch_all_averaged_preds)
# Out:
# 1376

# %%
catch_all_averaged_preds[0]
# Out:
# array([6.768347 , 6.590034 , 6.5614896, 7.9800763, 7.4533534, 6.8691688,
#        7.252766 ], dtype=float32)

# %%
Forecasted_values_df = pd.DataFrame(catch_all_averaged_preds).T

# %%
Forecasted_values_df.shape
# Out:
# (7, 1376)

# %%
Forecasted_values_df.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  6.768347  6.504449  5.692133  5.619357  7.481549  7.623435  9.139009
# 1  6.590034  6.303134  5.608032  5.561688  6.558194  7.217565  8.959716
# 2  6.561490  6.188662  5.345675  5.489680  6.822959  7.191832  8.969345
# 3  7.980076  7.896843  6.597255  6.680488  8.064613  8.429735  9.991206
# 4  7.453353  7.427403  6.075562  6.360754  7.132895  8.070671  9.506265
#
#        7         8         9     ...      1366      1367      1368      1369  \
# 0  8.664082  7.479198  5.747657  ...  0.084196  0.082878  0.084437  0.080529
# 1  8.609704  7.570258  5.704913  ...  0.083148  0.082448  0.083361  0.082901
# 2  8.223537  7.231955  5.718664  ...  0.068068  0.069212  0.070969  0.074307
# 3  9.400485  8.292189  6.307174  ...  0.088305  0.081965  0.085403  0.083246
# 4  8.866198  7.813038  5.975635  ...  0.101802  0.094838  0.092873  0.092208
#
#        1370      1371      1372      1373      1374      1375
# 0  0.084559  0.081488  0.082337  0.083654  0.085276  0.005114
# 1  0.083712  0.080242  0.081064  0.085431  0.084622  0.005628
# 2  0.077514  0.075949  0.075090  0.078980  0.078859  0.005139
# 3  0.085335  0.081550  0.083656  0.083881  0.083109  0.005047
# 4  0.092813  0.088813  0.089277  0.085672  0.087238  0.005032
#
# [5 rows x 1376 columns]

# %%
# give column names here
Forecasted_values_df.columns = ['forecasted_val_' + str(i) for i in range(1376)]

# %%
Forecasted_values_df.head()
# Out:
#    forecasted_val_0  forecasted_val_1  forecasted_val_2  forecasted_val_3  \
# 0          6.768347          6.504449          5.692133          5.619357
# 1          6.590034          6.303134          5.608032          5.561688
# 2          6.561490          6.188662          5.345675          5.489680
# 3          7.980076          7.896843          6.597255          6.680488
# 4          7.453353          7.427403          6.075562          6.360754
#
#    forecasted_val_4  forecasted_val_5  forecasted_val_6  forecasted_val_7  \
# 0          7.481549          7.623435          9.139009          8.664082
# 1          6.558194          7.217565          8.959716          8.609704
# 2          6.822959          7.191832          8.969345          8.223537
# 3          8.064613          8.429735          9.991206          9.400485
# 4          7.132895          8.070671          9.506265          8.866198
#
#    forecasted_val_8  forecasted_val_9  ...  forecasted_val_1366  \
# 0          7.479198          5.747657  ...             0.084196
# 1          7.570258          5.704913  ...             0.083148
# 2          7.231955          5.718664  ...             0.068068
# 3          8.292189          6.307174  ...             0.088305
# 4          7.813038          5.975635  ...             0.101802
#
#    forecasted_val_1367  forecasted_val_1368  forecasted_val_1369  \
# 0             0.082878             0.084437             0.080529
# 1             0.082448             0.083361             0.082901
# 2             0.069212             0.070969             0.074307
# 3             0.081965             0.085403             0.083246
# 4             0.094838             0.092873             0.092208
#
#    forecasted_val_1370  forecasted_val_1371  forecasted_val_1372  \
# 0             0.084559             0.081488             0.082337
# 1             0.083712             0.080242             0.081064
# 2             0.077514             0.075949             0.075090
# 3             0.085335             0.081550             0.083656
# 4             0.092813             0.088813             0.089277
#
#    forecasted_val_1373  forecasted_val_1374  forecasted_val_1375
# 0             0.083654             0.085276             0.005114
# 1             0.085431             0.084622             0.005628
# 2             0.078980             0.078859             0.005139
# 3             0.083881             0.083109             0.005047
# 4             0.085672             0.087238             0.005032
#
# [5 rows x 1376 columns]

# %%
# get the min and max values here?

# %%
Forecasted_values_df.values.min(), Forecasted_values_df.values.max()
# Out:
# (0.004885524, 18.70265)

# %%
# notice that, there are a lot of values which seem to be greater than 20 - this seems like an okay value to have a cut off - should we try to get the row and column indices of these values? Maybe we need to run these later individually until we get stable values?

# %%
mask_gt_20 = Forecasted_values_df > 20

# %%
resulting_df = Forecasted_values_df[mask_gt_20].stack().reset_index()

# %%
resulting_df.head()
# Out:
# Empty DataFrame
# Columns: [level_0, level_1, 0]
# Index: []

# %%
resulting_df.shape
# Out:
# (0, 3)

# %%
resulting_df.columns = ['row_index', 'column_name', 'forecasted_val']

# %%
resulting_df.head()
# Out:
# Empty DataFrame
# Columns: [row_index, column_name, forecasted_val]
# Index: []

# %%
# how many coumns do we need to focus on?
resulting_df['column_name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# notice that there are 347 py scripts that we may need to rerun

# %%
# What are the subwindow names?

# %%
sub_window_names = list(set(resulting_df['column_name']))
sub_window_names.sort()

# %%
# sub_window_names - but this is not properly sorted

# %%
sub_window_numbers = [val.split('_')[-1] for val in resulting_df['column_name']]
sub_window_int = [int(i) for i in sub_window_numbers]
sub_window_int.sort()

# %%
len(sub_window_int)
# Out:
# 0

# %%
unique_subwindow_int = list(set(sub_window_int))

# %%
len(unique_subwindow_int)
# Out:
# 0

# %%
unique_subwindow_int.sort()

# %%
sub_window_names_final = ['forecasted_val_' + str(i) for i in unique_subwindow_int]

# %%
sub_window_names_final # cool, so we need to look into individually running these scripts?
# Out:
# []

# %%
# We are waiting to see if changing the prioirs are going to give us a direction we should proceed in

# %%
# The maximmum is an absurd amount - where is this coming from ? Do we need to manually fix it? Let's see
# how many of teh values in the above dataframe are more than 10?

# %%
# Maybe see to this once all columns are arranged in a single column?

# %%
exp_true.columns = ['True_val_' + str(i) for i in range(1376)]

# %%
exp_true.head()
# Out:
#    True_val_0  True_val_1  True_val_2  True_val_3  True_val_4  True_val_5  \
# 0    7.997484    7.943025    6.943698    5.998227    6.893819    7.999327
# 1    7.000000    6.477448    5.346575    5.999997    6.579756    8.270914
# 2    6.999308    6.210626    5.984875    5.993741    6.007584    8.015235
# 3    5.999997    5.945537    5.001344    6.500894    7.999962    7.999996
# 4    4.000031    3.977478    3.006390    4.952668    5.013793    5.013792
#
#    True_val_6  True_val_7  True_val_8  True_val_9  ...  True_val_1366  \
# 0    9.041387    8.880806    6.363811    5.404401  ...       0.000674
# 1    8.954896    7.865375    6.632716    4.146502  ...       0.000000
# 2    8.202369    6.333913    5.867211    4.211305  ...       0.000000
# 3    7.998670    6.115386    4.944212    3.036338  ...       0.000000
# 4    4.513766    3.991206    2.360337    2.013762  ...       0.512943
#
#    True_val_1367  True_val_1368  True_val_1369  True_val_1370  True_val_1371  \
# 0       0.000674       0.000674       0.000674       0.000674       0.000674
# 1       0.000000       0.000000       0.000000       0.000000       0.000000
# 2       0.000000       0.000000       0.000000       0.000000       0.000000
# 3       0.000000       0.000000       0.000000       0.000000       0.000000
# 4       0.512943       0.512943       0.512943       0.512943       0.512943
#
#    True_val_1372  True_val_1373  True_val_1374  True_val_1375
# 0       0.000674       0.000489   8.526243e-09       0.000000
# 1       0.000000       0.000000   0.000000e+00       0.000000
# 2       0.000000       0.000000   0.000000e+00       0.000000
# 3       0.000000       0.000000   0.000000e+00       0.000000
# 4       0.512943       0.512943   5.129428e-01       0.485712
#
# [5 rows x 1376 columns]

# %%
# I think at this point we can go ahead and get the metrics for inference computed?

# %%
# exp_true.keys()

# %%
# exp_true.values.shape

# %%
# use one column for both dataframes? that way it will be easier to compute the metrics?

# %%
# Also something to keep in mind here is that the subwindow sizes are very small - 30*30 - this was intentional as we had to do the seq-2-seq model and they are data hungry - therefore having a 300*300 window size was not feasible

# %%
exp_true_onecol = pd.DataFrame(exp_true.to_numpy().ravel(order = 'F'), columns=["True_values"])

# %%
exp_true_onecol.head()
# Out:
#    True_values
# 0     7.997484
# 1     7.000000
# 2     6.999308
# 3     5.999997
# 4     4.000031

# %%
exp_true_onecol.shape
# Out:
# (9632, 1)

# %%
3072*7
# Out:
# 21504

# %%
exp_predicted_onecol = pd.DataFrame(Forecasted_values_df.to_numpy().ravel(order = 'F'), columns=["Forecasted_values"])

# %%
exp_predicted_onecol.head()
# Out:
#    Forecasted_values
# 0           6.768347
# 1           6.590034
# 2           6.561490
# 3           7.980076
# 4           7.453353

# %%
exp_predicted_onecol.tail()
# Out:
#       Forecasted_values
# 9627           0.005139
# 9628           0.005047
# 9629           0.005032
# 9630           0.004886
# 9631           0.004886

# %%
exp_predicted_onecol.shape
# Out:
# (9632, 1)

# %%
# how many values are > 10? - 503 - This still feels like an absolutely high value. Should we change the priors? Need to look into this. 
# how many values are > 100? - 163
# how many values are > 1000? - 58
# how many values are > 10000? - 18
# how many values are > 100000? - 5

# %%
values_greater_than_10 = []
greater_than_10_df_index = []
for i, val in enumerate(range(exp_predicted_onecol.shape[0])):
    value = exp_predicted_onecol['Forecasted_values'][val]
    if value >= 10:
        values_greater_than_10.append(value)
        greater_than_10_df_index.append(i)

# %%
len(values_greater_than_10)
# Out:
# 76

# %%
# values_greater_than_10

# %%
# greater_than_10_df_index

# %%
# enumerate(exp_predicted_onecol['Forecasted_values'][0])

# %%
# I think at this point, we should be looking inot other blocks too, to see if we see weird results like this?

# %%
# compute the metrics - these would look really small as the values we have are really small

# %%
# blockwise mean squared error
rmse = np.sqrt(mean_squared_error(exp_true_onecol['True_values'], exp_predicted_onecol['Forecasted_values']))
rmse
# Out:
# 1.6370359183730847

# %%
mae = mean_absolute_error(exp_true_onecol['True_values'], exp_predicted_onecol['Forecasted_values'])
mae
# Out:
# 1.1497634047389802

# %%
corr = pearsonr(exp_true_onecol['True_values'], exp_predicted_onecol['Forecasted_values'])
corr[0]
# Out:
# 0.8078426409821438

# %%
r2 = r2_score(exp_true_onecol['True_values'], exp_predicted_onecol['Forecasted_values'])
r2
# Out:
# 0.4942650019386051

# %%
plt.figure(figsize = (8,8))
plt.scatter(exp_true_onecol['True_values'], exp_predicted_onecol['Forecasted_values'], s = 10)
plt.xlabel("True density")
plt.ylabel("Predicted density")
# Add the y = x line
plt.plot([0, 3], [0, 3], color='green', label='y = x')
plt.legend()
plt.show()

# %%
# At this point let's look at the true and predicted value distributions - overlay the histograms

# Plot histogram of two columns
plt.hist(exp_true_onecol['True_values'], 
         bins=30, 
         label=[' True values'], 
         alpha=0.5, color = 'blue')  # alpha = transparency
plt.hist(exp_predicted_onecol['Forecasted_values'], 
         bins=30, 
         label=['Predicted values'], 
         alpha=0.5, color = 'red') 
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Two Columns")
plt.legend()
plt.show()

# %%
# Should we try to get the values separated by 0s?

# %%
# how to do this? Maybe we need to take the indices from the true values df, and subset accordingly?

# %%
# so create a mask 0 with the true values 0s - we need the indices of this

# %%
mask_zero = exp_true_onecol['True_values'].eq(0)

# %%
# separate the zero and non-zero indices
idx_zero = exp_true_onecol.index[mask_zero]
idx_nonzero = exp_true_onecol.index[-mask_zero]

# %%
# how many zero values?
idx_zero.shape
# Out:
# (1131,)

# %%
910*7
# Out:
# 6370

# %%
# how many non-zeor values
idx_nonzero.shape
# Out:
# (8501,)

# %%
# sanity check
idx_nonzero.shape[0] + idx_zero.shape[0]
# Out:
# 9632

# %%
# Subset both dataframes with the same indices
df_true_zero  = exp_true_onecol.loc[idx_zero]
df_pred_zero  = exp_predicted_onecol.loc[idx_zero]
df_true_nz    = exp_true_onecol.loc[idx_nonzero]
df_pred_nz    = exp_predicted_onecol.loc[idx_nonzero]

# %%
df_true_zero.shape, df_pred_zero.shape
# Out:
# ((1131, 1), (1131, 1))

# %%
df_true_zero.head()
# Out:
#      True_values
# 216          0.0
# 223          0.0
# 230          0.0
# 237          0.0
# 244          0.0

# %%
df_pred_zero.head()
# Out:
#      Forecasted_values
# 216           5.671812
# 223           5.899667
# 230           5.918149
# 237           5.795671
# 244           5.448503

# %%
df_true_nz.head()
# Out:
#    True_values
# 0     7.997484
# 1     7.000000
# 2     6.999308
# 3     5.999997
# 4     4.000031

# %%
df_pred_nz.head()
# Out:
#    Forecasted_values
# 0           6.768347
# 1           6.590034
# 2           6.561490
# 3           7.980076
# 4           7.453353

# %%
# create the separate scatterplots for these

# %%
# For zero-data
plt.figure(figsize = (8,8))
plt.scatter(df_true_zero['True_values'], df_pred_zero['Forecasted_values'], s = 10)
plt.title("Scatter plot when the True densities are zeros")
plt.xlabel("True densities")
plt.ylabel("Forecasted densities")
plt.show()

# %%
# Plot histogram of two columns
plt.hist(df_true_zero['True_values'], 
         bins=30, 
         label=[' True values'], 
         alpha=0.5, color = 'blue')  # alpha = transparency
plt.hist(df_pred_zero['Forecasted_values'], 
         bins=30, 
         label=['Predicted values'], 
         alpha=0.5, color = 'red') 
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Two Columns")
plt.legend()
plt.show()

# %%
# For non-zero data
plt.figure(figsize = (8,8))
plt.scatter(df_true_nz['True_values'], df_pred_nz['Forecasted_values'], s = 10)
plt.title("Scatter plot when the True densities are non-zeros")
# also plot the y = x line?
plt.plot([0, 3], [0, 3], color='green', label='y = x')
plt.xlabel("True densities")
plt.ylabel("Forecasted densities")
plt.show()

# %%
# Plot histogram of two columns
plt.hist(df_true_nz['True_values'], 
         bins=30, 
         label=[' True values'], 
         alpha=0.5, color = 'blue')  # alpha = transparency
plt.hist(df_pred_nz['Forecasted_values'], 
         bins=30, 
         label=['Predicted values'], 
         alpha=0.5, color = 'red') 
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Two Columns")
plt.legend()
plt.show()

# %%
# not that great - but maybe the model is not doing as well as we need due to the number of zeros we had considered during the model training phase?

# %%
# Maybe get the metrics for teh reduced subsets of data as well

# %%
# All zeros

# %%
rmse_zero =  np.sqrt(mean_squared_error(df_true_zero['True_values'], df_pred_zero['Forecasted_values']))
rmse_zero
# Out:
# 0.9555690902713242

# %%
mae_zero = mean_absolute_error(df_true_zero['True_values'], df_pred_zero['Forecasted_values'])
mae_zero
# Out:
# 0.618759241722982

# %%
corr_zero = pearsonr(df_true_zero['True_values'], df_pred_zero['Forecasted_values'])
# Out:
# /mnt/nrdstor/statsgeneral/gayara/tfp_cpu_env/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
corr_zero
# Out:
# PearsonRResult(statistic=nan, pvalue=nan)

# %%
r2_zero = r2_score(df_true_nz['True_values'], df_pred_nz['Forecasted_values'])
r2_zero
# Out:
# 0.3408845345857823

# %%
# non zeros

# %%
rmse_nzero =  np.sqrt(mean_squared_error(df_true_nz['True_values'], df_pred_nz['Forecasted_values']))
rmse_nzero
# Out:
# 1.7073206657255664

# %%
mae_nzero = mean_absolute_error(df_true_nz['True_values'], df_pred_nz['Forecasted_values'])
mae_nzero
# Out:
# 1.2204098826087713

# %%
corr_nzero = pearsonr(df_true_nz['True_values'], df_pred_nz['Forecasted_values'])

# %%
corr_nzero
# Out:
# PearsonRResult(statistic=0.7577856766639184, pvalue=0.0)

# %%
r2_nzero = r2_score(df_true_nz['True_values'], df_pred_nz['Forecasted_values'])
r2_nzero
# Out:
# 0.3408845345857823

# %% [markdown]
# Credible Intervals

# %%
all_forecasts_npy_files = ['all_forecasts_sub_' + str(i) + '.npy' for i in range(1376)]

# %%
# %%time
loaded_npy_files = []
for file in all_forecasts_npy_files:
    joined_path = os.path.join(path_to_dfs, file)
    load_file = np.load(joined_path)
    # notice we are averaging the preds across the chains before exponentiation
    mean_file = np.mean(np.exp(load_file)-1, axis = 1)
    loaded_npy_files.append(mean_file)
# Out:
# CPU times: user 340 ms, sys: 98.3 ms, total: 438 ms
# Wall time: 440 ms

# %%
len(loaded_npy_files)
# Out:
# 1376

# %%
loaded_npy_files[0].shape
# Out:
# (1000, 7)

# %%
# Maybe we should not get rid of the negatives? - As for the percentiles we will else never capture the true values of zeros?

# %%
# yeah, let's proceed with these

# %%
# how to arrange these though? - might need to think this through a little

# %%
exp_true.shape
# Out:
# (7, 1376)

# %%
# where is the lsit of the forecasted range of values? - loaded_npy_files

# %%
len(loaded_npy_files)
# Out:
# 1376

# %%
loaded_npy_files[0].shape
# Out:
# (1000, 7)

# %%
# Okay, I think we need to move along the loaded file and also its axis 1 to get the percentile values in order.

# %%
# create a for loop for this? - and later maybe even a function so we do not need to repeat everything for each block separately

# %%
# I think we also need to catch the percentiles?

# %%
# Let's try all these?

# %%
trial_0 = loaded_npy_files[0][:,0]

# %%
trial_0.shape
# Out:
# (1000,)

# %%
trial_li = np.percentile(trial_0, axis = 0, q = (2.5, 97.5))

# %%
# trial_0.min(), trial_0.max()

# %%
trial_li
# Out:
# array([ 2.20668188, 16.45005541])

# %%
trial_li[0], trial_li[1]
# Out:
# (2.2066818833351136, 16.450055408477784)

# %%
lower_and_upper_limits = [] 
for j in range(loaded_npy_files[0].shape[1]):
    values = loaded_npy_files[0][:,j]
    # compute the lower and upper bounds?
    li = np.percentile(values, axis = 0, q = (2.5, 97.5))[0]    
    ui = np.percentile(values, axis = 0, q = (2.5, 97.5))[1]
    lower_and_upper_limits.append((li, ui))

# %%
lower_and_upper_limits
# Out:
# [(2.2066818833351136, 16.450055408477784),
#  (2.1275633811950683, 17.548658180236806),
#  (1.6888390600681304, 17.989413690567016),
#  (1.5635931432247163, 22.623880386352536),
#  (1.50192389190197, 21.399304580688472),
#  (0.9762241661548615, 20.755616664886464),
#  (1.0025478839874267, 23.53973331451416)]

# %%
# %%time
# Do this for all files?
catch_all_percentiles = []
for i in range(len(loaded_npy_files)):
    all_lower_and_upper_limits = [] 
    for j in range(loaded_npy_files[i].shape[1]):
        values = loaded_npy_files[i][:,j]
        # compute the lower and upper bounds?
        li = np.percentile(values, axis = 0, q = (2.5, 97.5))[0]    
        ui = np.percentile(values, axis = 0, q = (2.5, 97.5))[1]
        all_lower_and_upper_limits.append((li, ui))
    catch_all_percentiles.append(all_lower_and_upper_limits)
# Out:
# CPU times: user 1.38 s, sys: 4.67 ms, total: 1.39 s
# Wall time: 1.39 s

# %%
len(catch_all_percentiles)
# Out:
# 1376

# %%
catch_inside_length = []
for limit_values in catch_all_percentiles:
    length = len(limit_values)
    catch_inside_length.append(length)

# %%
np.mean(catch_inside_length)
# Out:
# 7.0

# %%
# We may need a multitude of sanity checks to make sure we are correctly computing the coverages and widths. Now at this point, we can go ahead and compute the CI widths using the credible intervals? As this computation seems fairly simple?

# %%
len(catch_all_percentiles[0])
# Out:
# 7

# %%
all_percentiles_for_widths = [item for limit_values in catch_all_percentiles for item in limit_values]

# %%
len(all_percentiles_for_widths)
# Out:
# 9632

# %%
# do some sanity check?

# %%
catch_all_percentiles[1]
# Out:
# [(2.515983098745346, 14.620332908630365),
#  (1.8937567472457886, 14.68702299594879),
#  (1.6896562159061432, 15.372630548477169),
#  (1.8044827103614807, 23.281016302108757),
#  (1.3192552655935288, 22.50755419731138),
#  (1.3467129170894623, 21.093559837341303),
#  (1.2027005970478057, 23.472905015945422)]

# %%
all_percentiles_for_widths[7:14]
# Out:
# [(2.515983098745346, 14.620332908630365),
#  (1.8937567472457886, 14.68702299594879),
#  (1.6896562159061432, 15.372630548477169),
#  (1.8044827103614807, 23.281016302108757),
#  (1.3192552655935288, 22.50755419731138),
#  (1.3467129170894623, 21.093559837341303),
#  (1.2027005970478057, 23.472905015945422)]

# %%
# seems this is right, let's move forward with the computation of the CI widths?

# %%
catch_wdths = []
for values in all_percentiles_for_widths:
    width = values[1] - values[0]
    catch_wdths.append(width)

# %%
# average CI width
Average_CI_width = np.mean(catch_wdths)
Average_CI_width
# Out:
# 8.839592382380625

# %%
# do a few sanity checks  before we proceed?

# %%
catch_wdths[0:7]
# Out:
# [14.24337352514267,
#  15.421094799041738,
#  16.300574630498886,
#  21.06028724312782,
#  19.8973806887865,
#  19.779392498731603,
#  22.537185430526733]

# %%
print(catch_all_percentiles[0][0][1] - catch_all_percentiles[0][0][0])
print(catch_all_percentiles[0][1][1] - catch_all_percentiles[0][1][0])
print(catch_all_percentiles[0][2][1] - catch_all_percentiles[0][2][0])
print(catch_all_percentiles[0][3][1] - catch_all_percentiles[0][3][0])
print(catch_all_percentiles[0][4][1] - catch_all_percentiles[0][4][0])
print(catch_all_percentiles[0][5][1] - catch_all_percentiles[0][5][0])
print(catch_all_percentiles[0][6][1] - catch_all_percentiles[0][6][0])
# Out:
# 14.24337352514267
# 15.421094799041738
# 16.300574630498886
# 21.06028724312782
# 19.8973806887865
# 19.779392498731603
# 22.537185430526733

# %%
# Okay, we can move on now

# %%
# What about the coverage?
# Now this list - all_percentiles_for_widths - this is in the oder of the subwindows - but before proceeding to the next subwindow, it also tracks across the 7 time periods.
# so now, we have the true values in a dataframe in the shape (7,910), we can stack these ina single column  - and basically then have to track if this value is inbetween the two upper and lower limits in the list all_percentiles_for_widths.

# %%
# cool, so let's get this true values dataset arranged  in one single column?

# %%
# actually, we have already done that

# %%
exp_true_onecol.shape
# Out:
# (9632, 1)

# %%
exp_true_onecol.head()
# Out:
#    True_values
# 0     7.997484
# 1     7.000000
# 2     6.999308
# 3     5.999997
# 4     4.000031

# %%
All_exp_true_vals_array = exp_true_onecol.values.reshape(-1)

# %%
All_exp_true_vals_array.shape
# Out:
# (9632,)

# %%
All_exp_true_vals_array.min(), All_exp_true_vals_array.max()
# Out:
# (0.0, 10.74842430108513)

# %%
# cool, now check if this value is inbetween the upper and the lower limits contained in the list - all_percentiles_for_widths

# %%
Catch_all_indicators = []
for i in range(All_exp_true_vals_array.shape[0]):
    true_value = All_exp_true_vals_array[i]
    li_val = all_percentiles_for_widths[i][0]
    ui_val = all_percentiles_for_widths[i][1]
    ind_train = (true_value >= li_val) & (true_value <= ui_val)
    Catch_all_indicators.append(ind_train)

# %%
coverage_val = np.mean(Catch_all_indicators)
coverage_val
# Out:
# 0.9305440199335548

# %%
# I think we are ready to replicate this for the rest of the blocks? Let's push the recent work to GitHub

# %%
# define a function to get the post-hoc prediction
def prediction_on_test_data(preds_array, stride = 24, kernel_size = 300):

    img_height = 768 # we might need to verify this value
    # get the image weight
    img_width = 1024 # we might need to verify this value

    
    # create an empty density map
    Density_map = np.zeros((img_height, img_width))

    # create an empty counts map
    counts_map = np.zeros((img_height, img_width))
    
    # now, for every window, we will keep adding the values together and also add the counts
    counter = 0
#     need a counter to move into each predicted value in the pred values list
    for ii in range(0, img_height, stride):
        for jj in range(0, img_width, stride):
#         operations for density map
#             get the window of interest
            new_window = Density_map[ii:ii + kernel_size,jj:jj+kernel_size]
#     fill each with the value c_k
            counts_window = np.full((new_window.shape[0], new_window.shape[1]), preds_array[counter])
#     get the shapes of this new window
            cw_height = counts_window.shape[0]
            cw_width = counts_window.shape[1]
#         Do c_k/r_2
            counts_window_new = counts_window/(cw_height*cw_width)
#     This is the value in the window now
            value_window = counts_window_new
#     place the values in the corrsponding area of the density map
            Density_map[ii:ii + kernel_size,jj:jj+kernel_size] = new_window + value_window

#         Let's now focus on capturing the counts of the windows
            new_window_c = counts_map[ii:ii + kernel_size,jj:jj+kernel_size]
#     get the counts area
            count = np.ones((new_window_c.shape[0], new_window_c.shape[1]))
#     keep adding the counts to reflect the addition of densities
            counts_map[ii:ii + kernel_size,jj:jj+kernel_size] = new_window_c + count
#     increase the counter
            counter = counter + 1
            
#         get the normalized count
    normalized_counts = np.divide(Density_map, counts_map)
    
#     entire count on the test set
    pred_on_test = np.sum(normalized_counts)
    
#     return the predicted value
    return(pred_on_test, normalized_counts)

# %%
Forecasted_values_df.shape
# Out:
# (7, 1376)

# %%
Forecasted_values_df.values.shape
# Out:
# (7, 1376)

# %%
# Access just the first row?

# %%
Forecasted_values_df.values[0,:].shape
# Out:
# (1376,)

# %%
# use this to get the preds?

# %%
test_im_0_preds = prediction_on_test_data(Forecasted_values_df.values[0,:], stride = 24, kernel_size = 300)

# %%
test_im_0_preds[0]
# Out:
# 47.66643750479803

# %%
# get the values forecasted in a loop?
predicted_test_values = []
for i in range(7):
    pred_val = prediction_on_test_data(Forecasted_values_df.values[i,:], stride = 24, kernel_size = 300)[0]
    predicted_test_values.append(pred_val)

# %%
predicted_test_values
# Out:
# [47.66643750479803,
#  47.21652258776871,
#  45.564815282099374,
#  50.623527405636416,
#  49.718797048045865,
#  49.04184095464575,
#  48.572565481457325]

# %%
# Okay, there's some seroius shit happening I think with those very high values - we need to figuer out what to do
